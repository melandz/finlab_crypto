# %% [markdown]
# <a href="https://colab.research.google.com/github/melandz/finlab_crypto/blob/master/Fugle_API_workshop1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 前置作業

# %% [markdown]
# ## 安裝相關套件

# %%
# !pip install lineTool
# !pip install fugle-trade -U
# !pip install fugle-realtime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting lineTool
#   Downloading lineTool-1.0.3.tar.gz (756 bytes)
# Building wheels for collected packages: lineTool
#   Building wheel for lineTool (setup.py) ... done
#   Created wheel for lineTool: filename=lineTool-1.0.3-py3-none-any.whl size=1464 sha256=c589d98840057ec6ed0cc38ecfba14da80f54780a908fb61afca35cbcb69acbd
#   Stored in directory: /root/.cache/pip/wheels/7a/d0/c1/f626ef4b03a3ee37bac2d52f3377138697c2fab58c88af8d10
# Successfully built lineTool
# Installing collected packages: lineTool
# Successfully installed lineTool-1.0.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fugle-trade
#   Downloading fugle_trade-0.4.0-py3-none-any.whl (8.2 kB)
# Collecting keyrings.cryptfile==1.3.8
#   Downloading keyrings.cryptfile-1.3.8.tar.gz (18 kB)
# Collecting fugle-trade-core==0.4.1
#   Downloading fugle_trade_core-0.4.1-cp37-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (21.5 MB)
#      |████████████████████████████████| 21.5 MB 1.3 MB/s
# Collecting websocket-client==1.2.1
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.2 MB/s
# Collecting keyring==23.5.0
#   Downloading keyring-23.5.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.7/dist-packages (from keyring==23.5.0->fugle-trade) (4.13.0)
# Collecting SecretStorage>=3.2
#   Downloading SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.8.0-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 4.6 MB/s
# Collecting argon2_cffi
#   Downloading argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Collecting pycryptodome
#   Downloading pycryptodome-3.15.0-cp35-abi3-manylinux2010_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 59.3 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3.6->keyring==23.5.0->fugle-trade) (3.10.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3.6->keyring==23.5.0->fugle-trade) (4.1.1)
# Collecting cryptography>=2.0
#   Downloading cryptography-38.0.3-cp36-abi3-manylinux_2_24_x86_64.whl (4.1 MB)
#      |████████████████████████████████| 4.1 MB 48.1 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring==23.5.0->fugle-trade) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring==23.5.0->fugle-trade) (2.21)
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
#      |████████████████████████████████| 86 kB 5.4 MB/s
# Building wheels for collected packages: keyrings.cryptfile
#   Building wheel for keyrings.cryptfile (setup.py) ... done
#   Created wheel for keyrings.cryptfile: filename=keyrings.cryptfile-1.3.8-py2.py3-none-any.whl size=17836 sha256=191369a562eb6a270870c0543f2d0f003566c8d20df64a56e2dd1c6af5b0ba3f
#   Stored in directory: /root/.cache/pip/wheels/4d/27/4d/c5d8637dc5fd0fac41b838ca49f0bbbde7b6cf47b8fa4339da
# Successfully built keyrings.cryptfile
# Installing collected packages: jeepney, cryptography, SecretStorage, argon2-cffi-bindings, pycryptodome, keyring, argon2-cffi, websocket-client, keyrings.cryptfile, fugle-trade-core, fugle-trade
# Successfully installed SecretStorage-3.3.3 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 cryptography-38.0.3 fugle-trade-0.4.0 fugle-trade-core-0.4.1 jeepney-0.8.0 keyring-23.5.0 keyrings.cryptfile-1.3.8 pycryptodome-3.15.0 websocket-client-1.2.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fugle-realtime
#   Downloading fugle_realtime-0.3.1-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: websocket-client<2.0.0,>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from fugle-realtime) (1.2.1)
# Collecting requests<3.0.0,>=2.26.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.0 MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.26.0->fugle-realtime) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.26.0->fugle-realtime) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.26.0->fugle-realtime) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.26.0->fugle-realtime) (1.24.3)
# Installing collected packages: requests, fugle-realtime
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# Successfully installed fugle-realtime-0.3.1 requests-2.28.1

# %%
import datetime
import lineTool
import fugle_trade
from fugle_realtime import WebSocketClient
import pandas as pd
import requests
import time
import json
from fugle_trade.constant import *
from fugle_trade.order import OrderObject
from fugle_trade.sdk import SDK
from configparser import ConfigParser

# %% [markdown]
# ## 取得相關 Token 及輸入設定檔

# %%
# Set Your Fugle API Token from https://developer.fugle.tw/docs/key/ （技術文件右上角的金鑰申請頁面）
API_TOKEN = "demo"#'YOUR_API_TOKEN'

# Set Your line Token from https://notify-bot.line.me/my/ -> 點選發行權杖
LINE_NOTIFY_TOKEN = 'YOUR_LINE_NOTIFY_TOKEN'

# %%
# 連結富果交易 API 設定檔並登入
config = ConfigParser()
config.read('./config_colab.ini') # 使用模擬環境

# 登入
sdk = SDK(config)
sdk.login()
# Out:
# Enter esun account password:
# ··········
# Please set a password for your new keyring: ··········
# Please confirm the password: ··········
# Enter cert password:
# ··········

# %% [markdown]
# ### 下單測試

# %%
# 下單測試
symbol_id = "0050"
qty = 1

order = OrderObject(
    buy_sell=Action.Buy,
    price_flag=PriceFlag.LimitDown,
    price = '',
    stock_no=symbol_id,
    quantity=qty,
    ap_code=APCode.Common,
    trade=Trade.Cash
)
sdk.place_order(order)
# Out:
# {'ord_date': '20221118',
#  'ord_time': '185531288',
#  'ord_type': '1',
#  'ord_no': 'P0CCXDFH',
#  'ret_code': '000000',
#  'ret_msg': '',
#  'work_date': '20221121'}

# %% [markdown]
# # 標的選擇

# %%
# 上市櫃已發行股數 data -> https://github.com/intinglin/fugle_trading_API/blob/main/shares_data.xlsx
total_data = pd.read_excel('shares_data.xlsx')

# %%
# 週轉率 =  成交量/ 已發行股數，串接富果歷史 API 方式計算
volume_list = []

for symbol_id in total_data['symbol_id'].tolist():

    url = f"https://api.fugle.tw/marketdata/v0.3/candles?symbolId={symbol_id}&apiToken={API_TOKEN}&from=2022-10-15&to=2022-10-25"
    
    try:
        volume = requests.get(url).json()['candles'][-1]['volume']

        volume_list.append([symbol_id,volume])
    
    except KeyError:
        
        pass

# %%
# 週轉率排行 -> 這部分如果是 finlab vip 透過 finlab 平台取得這些盤後資料，應該會方便許多

df = pd.merge(pd.DataFrame(volume_list, columns=['symbol_id','volume']),total_data)

df['turnover_rate'] = df['volume']/df['已發行普通股數或TDR原股發行股數']

df.sort_values(['turnover_rate','volume'], ascending=False).head(20)

# %% [markdown]
# # 程式碼實作

# %%
# 查看 server 時間 -> 與本地時間差八小時，因此下面的時間判斷需 -8
datetime.datetime.now()
# Out:
# datetime.datetime(2022, 10, 21, 1, 23, 21, 672730)

# %%
# gridTrading_strategy

class GridTrading:

    # 設定方便調整的參數有 股票代碼、網格大小的比例 以及初始部位
    def __init__(self, symbol_id, grid_size_ratio, first_position):
        
        # 初始化交易 API 並取得 sdk object
        self.sdk = self._init_fugle_trade()
        
        # 設定交易標的
        self.symbol_id = symbol_id

        # 首筆交易建倉幾張 -> 預計花 25% 的部位建倉
        self.first_position = first_position

        # 網格大小的比例 -> 與交易頻率有關
        self.grid_size_ratio = grid_size_ratio

        # 設定第一次買進的價格 -> 基準價
        self.base_price = None

        # 網格大小
        self.grid_size = None
        # 網格大小的比例 * 基準價 = 網格大小
        
        # 目前價格
        self.now_price = None
        
        # 目前持有部位數量
        self.now_position = 0

    # 交易 API 設定檔的部分
    def _init_fugle_trade(self):
        # 讀取設定檔
        config = ConfigParser()
        config.read('./config_colab.ini') # 使用模擬環境
        # 登入
        sdk = SDK(config)
        sdk.login()

        return sdk

    # 透過下面的 webSocket  function 取得最新價格
    def _on_new_price(self, message):
        json_data = json.loads(message)

        # 只使用整股最新價格
        if json_data['data']['info']['type'] == "EQUITY":
            # 更新目前價格
            self.now_price = json_data['data']['quote']['trade']['price']

            print(json_data['data']['quote']['trade']['price'])

    def create_ws_quote(self):
        ws_client = WebSocketClient(api_token=API_TOKEN)
        ws = ws_client.intraday.quote(symbolId=self.symbol_id, on_message=self._on_new_price)
        ws.run_async()
        time.sleep(2)

    def buy(self, qty):
        order = OrderObject(
            buy_sell=Action.Buy,
            price_flag=PriceFlag.Market,
            price = '',
            stock_no=self.symbol_id,
            quantity=qty,
            ap_code=APCode.Common,
            trade=Trade.Cash
        )
        #
        self.sdk.place_order(order)
        msg = '\n'+f'目前有 {str(self.now_position)} 張部位'+'\n'+'買進' + self.symbol_id + '\n' + str(qty) + "張" + '\n' + str(self.now_price) +'元'

        #line notify 觸發
        lineTool.lineNotify(LINE_NOTIFY_TOKEN, msg)

    def sell(self, qty):
        order = OrderObject(
            buy_sell=Action.Sell,
            price_flag=PriceFlag.Market,
            price = '',
            stock_no=self.symbol_id,
            quantity=qty,
            ap_code=APCode.Common,
            trade=Trade.DayTradingSell   # 現股當沖賣 的交易類別
        )
        #
        self.sdk.place_order(order)
        msg = '\n'+f'目前有 {str(self.now_position)} 張部位'+'\n'+'賣出' + self.symbol_id + '\n' + str(qty) + "張"+'\n'+ str(self.now_price) +'元'

        #line notify 觸發
        lineTool.lineNotify(LINE_NOTIFY_TOKEN, msg)

    # 在 13:25 後，如果還有部位時，因為這是當沖策略，所以會把所有部位全部賣出
    # 但因為交易規則的關係，不能以市價賣，但可以透過跌停價賣出

    def sell_allposition(self, qty):
        order = OrderObject(
            buy_sell=Action.Sell,
            price_flag=PriceFlag.LimitDown, # 跌停價賣出
            price = '',
            stock_no=self.symbol_id,
            quantity=qty,
            ap_code=APCode.Common,
            trade=Trade.DayTradingSell   # 現股當沖賣 的交易類別
        )
        
        self.sdk.place_order(order)
        msg = '\n'+f'目前有 {str(self.now_position)} 張部位'+'\n'+'賣出' + self.symbol_id + '\n' + str(qty) + "張"+'\n'+ str(self.now_price) +'元'
        
        #line notify 觸發
        lineTool.lineNotify(LINE_NOTIFY_TOKEN, msg)


    def run_trade(self):
        

        # 如果是盤中
        # while datetime.time(9-8, 0, 0) < datetime.datetime.now().time() < datetime.time(13-8, 25, 0) and self.new_price is not None:

        if self.base_price is None:
            # 設定第一次買進的價格
            self.base_price = self.now_price
            # 設定網格大小
            self.grid_size = self.base_price * self.grid_size_ratio

            # 買進部位
            self.now_position = self.first_position
            self.buy(self.now_position)
    

        # 此版本採用先買後賣的方式 -> 透過最新部位進行判斷
        if self.now_position > 0 and self.now_price >= self.base_price+((self.first_position+1 - self.now_position)*self.grid_size):

            # 賣出一部位
            self.sell(1)
            # 更新
            self.now_position = self.now_position - 1

        # 透過部位持有上限來計算下限價格
        elif self.now_position < (self.first_position)*4 and self.now_price <= self.base_price-((self.now_position - (self.first_position-1)) * self.grid_size):

            # 買進一部位
            self.buy(1)
            # 更新
            self.now_position = self.now_position + 1

        # 13:25 最後一盤無法以市價賣出， 需使用跌停價賣出所有部位
        if self.now_position > 0:
            self.sell_allposition(self.now_position)


if __name__ == '__main__':
    # 輸入要交易的標的，以第一筆成交價格的 0.5% 作為網格大小的比例
    gt = GridTrading('6150', 0.005, 2)
    gt.create_ws_quote()
    gt.run_trade()

# %% [markdown]
# 本程式無法全面考量各種風險 僅做為教學之用<br>
# 網格交易的當沖策略也存在著跌停賣不出去的風險 ，所以即使是當沖交易也應該要準備好相對應的交割款，才不會違約交割哦！

# %%
import pandas as pd
pd.DataFrame(sdk.get_order_results())
# Out:
#     work_date  ord_date   ord_time ord_status ord_no pre_ord_no stock_no  \
# 0    20221021  20221021  1310SS793          2  Z0245                6150
# 1    20221021  20221021  1310SS780          2  Z0243                6150
# 2    20221021  20221021  1310SS607          2  Z0250                6150
# 3    20221021  20221021  1310SS526          2  Z0246                6150
# 4    20221021  20221021  1310SS324          2  Z0248                6150
# ..        ...       ...        ...        ...    ...        ...      ...
# 247  20221021  20221021  0810SS626          2  Z0004   P0E000YB     3046
# 248  20221021  20221021  0810SS620          2  Z0003   P0E000YA     3046
# 249  20221021  20221021  0810SS615          2  Z0002   P0E000Y9     3046
# 250  20221021  20221021  0810SS585          2  Z0001   P0E000Y8     0050
# 251  20221021  20221021  0810SS210          2  Z0006                0050
#
#     buy_sell ap_code price_flag  ... mat_qty  cel_qty  celable  err_code  \
# 0          S       1          4  ...       0        0        2  00000000
# 1          S       1          4  ...       1        0        2  00000000
# 2          S       1          4  ...       0        0        2  00000000
# 3          S       1          4  ...       1        0        2  00000000
# 4          B       1          4  ...       2        0        2  00000000
# ..       ...     ...        ...  ...     ...      ...      ...       ...
# 247        B       1          4  ...       2        0        2  00000000
# 248        S       1          4  ...       1        0        2  00000000
# 249        B       1          4  ...       2        0        2  00000000
# 250        B       1          4  ...       1        0        2  00000000
# 251        B       1          4  ...       1        0        2  00000000
#
#      err_msg avg_price bs_flag org_qty_share  mat_qty_share cel_qty_share
# 0                  0.0       R          1000              0             0
# 1                  0.0       R          1000           1000             0
# 2                  0.0       R          2000              0             0
# 3                  0.0       R          1000           1000             0
# 4                  0.0       R          2000           2000             0
# ..       ...       ...     ...           ...            ...           ...
# 247                0.0       R          2000           2000             0
# 248                0.0       R          2000           1000             0
# 249                0.0       R          2000           2000             0
# 250                0.0       R          1000           1000             0
# 251                0.0       R          1000           1000             0
#
# [252 rows x 23 columns]
